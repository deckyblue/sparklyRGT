# %%
conda install -c conda-forge jupyterlab jupyterlab-git
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dexte\miniconda3
#
#   added / updated specs:
#     - jupyterlab
#     - jupyterlab-git
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     gitdb-4.0.7                |     pyhd8ed1ab_0          46 KB  conda-forge
#     gitpython-3.1.14           |     pyhd8ed1ab_0         110 KB  conda-forge
#     jupyter-server-mathjax-0.2.2|     pyhd8ed1ab_0         2.3 MB  conda-forge
#     jupyterlab-git-0.30.0      |     pyhd8ed1ab_0         283 KB  conda-forge
#     nbdime-3.0.0               |     pyhd8ed1ab_0         4.4 MB  conda-forge
#     pexpect-4.8.0              |     pyh9f0ad1d_2          47 KB  conda-forge
#     ptyprocess-0.7.0           |     pyhd3deb0d_0          16 KB  conda-forge
#     smmap-3.0.5                |     pyh44b312d_0          22 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         7.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   gitdb              conda-forge/noarch::gitdb-4.0.7-pyhd8ed1ab_0
#   gitpython          conda-forge/noarch::gitpython-3.1.14-pyhd8ed1ab_0
#   jupyter-server-ma~ conda-forge/noarch::jupyter-server-mathjax-0.2.2-pyhd8ed1ab_0
#   jupyterlab-git     conda-forge/noarch::jupyterlab-git-0.30.0-pyhd8ed1ab_0
#   nbdime             conda-forge/noarch::nbdime-3.0.0-pyhd8ed1ab_0
#   pexpect            conda-forge/noarch::pexpect-4.8.0-pyh9f0ad1d_2
#   ptyprocess         conda-forge/noarch::ptyprocess-0.7.0-pyhd3deb0d_0
#   smmap              conda-forge/noarch::smmap-3.0.5-pyh44b312d_0
#
#
#
# Downloading and Extracting Packages
#
# pexpect-4.8.0        | 47 KB     |            |   0%
# pexpect-4.8.0        | 47 KB     | ###4       |  34%
# pexpect-4.8.0        | 47 KB     | ########## | 100%
#
# gitdb-4.0.7          | 46 KB     |            |   0%
# gitdb-4.0.7          | 46 KB     | ########## | 100%
#
# ptyprocess-0.7.0     | 16 KB     |            |   0%
# ptyprocess-0.7.0     | 16 KB     | ########## | 100%
#
# gitpython-3.1.14     | 110 KB    |            |   0%
# gitpython-3.1.14     | 110 KB    | ########## | 100%
# gitpython-3.1.14     | 110 KB    | ########## | 100%
#
# jupyterlab-git-0.30. | 283 KB    |            |   0%
# jupyterlab-git-0.30. | 283 KB    | ########## | 100%
# jupyterlab-git-0.30. | 283 KB    | ########## | 100%
#
# smmap-3.0.5          | 22 KB     |            |   0%
# smmap-3.0.5          | 22 KB     | ########## | 100%
# smmap-3.0.5          | 22 KB     | ########## | 100%
#
# nbdime-3.0.0         | 4.4 MB    |            |   0%
# nbdime-3.0.0         | 4.4 MB    | ##6        |  26%
# nbdime-3.0.0         | 4.4 MB    | ########## | 100%
# nbdime-3.0.0         | 4.4 MB    | ########## | 100%
#
# jupyter-server-mathj | 2.3 MB    |            |   0%
# jupyter-server-mathj | 2.3 MB    | #########8 |  98%
# jupyter-server-mathj | 2.3 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !conda install --yes --prefix {sys.prefix} numpy
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dexte\miniconda3
#
#   added / updated specs:
#     - numpy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     mkl-service-2.3.0          |   py38h196d8e1_0          47 KB
#     mkl_fft-1.3.0              |   py38h46781fe_0         134 KB
#     mkl_random-1.1.1           |   py38h47e9c7a_0         245 KB
#     numpy-1.19.2               |   py38hadc3359_0          22 KB
#     numpy-base-1.19.2          |   py38ha3acd2a_0         3.8 MB
#     ------------------------------------------------------------
#                                            Total:         4.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/win-64::blas-1.0-mkl
#   mkl-service        pkgs/main/win-64::mkl-service-2.3.0-py38h196d8e1_0
#   mkl_fft            pkgs/main/win-64::mkl_fft-1.3.0-py38h46781fe_0
#   mkl_random         pkgs/main/win-64::mkl_random-1.1.1-py38h47e9c7a_0
#   numpy              pkgs/main/win-64::numpy-1.19.2-py38hadc3359_0
#   numpy-base         pkgs/main/win-64::numpy-base-1.19.2-py38ha3acd2a_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2020.12.~ --> pkgs/main::ca-certificates-2021.4.13-haa95532_1
#   conda              conda-forge::conda-4.10.1-py38haa244f~ --> pkgs/main::conda-4.10.1-py38haa95532_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            conda-forge::certifi-2020.12.5-py38ha~ --> pkgs/main::certifi-2020.12.5-py38haa95532_0
#   openssl            conda-forge::openssl-1.1.1k-h8ffe710_0 --> pkgs/main::openssl-1.1.1k-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# numpy-base-1.19.2    | 3.8 MB    |            |   0%
# numpy-base-1.19.2    | 3.8 MB    |            |   0%
# numpy-base-1.19.2    | 3.8 MB    | #9         |  20%
# numpy-base-1.19.2    | 3.8 MB    | ########## | 100%
# numpy-base-1.19.2    | 3.8 MB    | ########## | 100%
#
# mkl_fft-1.3.0        | 134 KB    |            |   0%
# mkl_fft-1.3.0        | 134 KB    | ########## | 100%
# mkl_fft-1.3.0        | 134 KB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 47 KB     |            |   0%
# mkl-service-2.3.0    | 47 KB     | ########## | 100%
# mkl-service-2.3.0    | 47 KB     | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# mkl_random-1.1.1     | 245 KB    |            |   0%
# mkl_random-1.1.1     | 245 KB    | ########## | 100%
# mkl_random-1.1.1     | 245 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import sys
# !conda install --yes --prefix {sys.prefix} pandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dexte\miniconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pandas-1.2.4               |   py38hd77b12b_0         7.9 MB
#     ------------------------------------------------------------
#                                            Total:         7.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandas             pkgs/main/win-64::pandas-1.2.4-py38hd77b12b_0
#
#
#
# Downloading and Extracting Packages
#
# pandas-1.2.4         | 7.9 MB    |            |   0%
# pandas-1.2.4         | 7.9 MB    |            |   0%
# pandas-1.2.4         | 7.9 MB    | #2         |  13%
# pandas-1.2.4         | 7.9 MB    | ######     |  60%
# pandas-1.2.4         | 7.9 MB    | ########## | 100%
# pandas-1.2.4         | 7.9 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import sys
# !conda install --yes --prefix {sys.prefix} matplotlib scipy
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# Warning: 2 possible package resolutions (only showing differing packages):
#   - defaults/win-64::libtiff-4.1.0-h56a325e_1, defaults/win-64::zstd-1.4.9-h19a0ad4_0
#   - defaults/win-64::libtiff-4.2.0-hd0e1b90_0, defaults/win-64::zstd-1.4.5-h04227a9_0done
#
# ## Package Plan ##
#
#   environment location: C:\Users\dexte\miniconda3
#
#   added / updated specs:
#     - matplotlib
#     - scipy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cycler-0.10.0              |           py38_0          14 KB
#     freetype-2.10.4            |       hd328e21_0         466 KB
#     icc_rt-2019.0.0            |       h0cc432a_1         6.0 MB
#     icu-58.2                   |       ha925a31_3         9.4 MB
#     jpeg-9b                    |       hb83a4c4_2         245 KB
#     kiwisolver-1.3.1           |   py38hd77b12b_0          52 KB
#     libpng-1.6.37              |       h2a8f88b_0         333 KB
#     libtiff-4.1.0              |       h56a325e_1         739 KB
#     lz4-c-1.9.3                |       h2bbff1b_0         131 KB
#     matplotlib-3.3.4           |   py38haa95532_0          27 KB
#     matplotlib-base-3.3.4      |   py38h49ac443_0         5.1 MB
#     olefile-0.46               |             py_0          33 KB
#     pillow-8.2.0               |   py38h4fa10fc_0         671 KB
#     pyqt-5.9.2                 |   py38ha925a31_4         3.2 MB
#     qt-5.9.7                   |   vc14h73c81de_0        72.5 MB
#     scipy-1.6.2                |   py38h14eb087_0        13.0 MB
#     sip-4.19.13                |   py38ha925a31_0         262 KB
#     tk-8.6.10                  |       he774522_0         2.7 MB
#     xz-5.2.5                   |       h62dcd97_0         244 KB
#     zstd-1.4.9                 |       h19a0ad4_0         478 KB
#     ------------------------------------------------------------
#                                            Total:       115.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   cycler             pkgs/main/win-64::cycler-0.10.0-py38_0
#   freetype           pkgs/main/win-64::freetype-2.10.4-hd328e21_0
#   icc_rt             pkgs/main/win-64::icc_rt-2019.0.0-h0cc432a_1
#   icu                pkgs/main/win-64::icu-58.2-ha925a31_3
#   jpeg               pkgs/main/win-64::jpeg-9b-hb83a4c4_2
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.3.1-py38hd77b12b_0
#   libpng             pkgs/main/win-64::libpng-1.6.37-h2a8f88b_0
#   libtiff            pkgs/main/win-64::libtiff-4.1.0-h56a325e_1
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.3-h2bbff1b_0
#   matplotlib         pkgs/main/win-64::matplotlib-3.3.4-py38haa95532_0
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.3.4-py38h49ac443_0
#   olefile            pkgs/main/noarch::olefile-0.46-py_0
#   pillow             pkgs/main/win-64::pillow-8.2.0-py38h4fa10fc_0
#   pyqt               pkgs/main/win-64::pyqt-5.9.2-py38ha925a31_4
#   qt                 pkgs/main/win-64::qt-5.9.7-vc14h73c81de_0
#   scipy              pkgs/main/win-64::scipy-1.6.2-py38h14eb087_0
#   sip                pkgs/main/win-64::sip-4.19.13-py38ha925a31_0
#   tk                 pkgs/main/win-64::tk-8.6.10-he774522_0
#   xz                 pkgs/main/win-64::xz-5.2.5-h62dcd97_0
#   zstd               pkgs/main/win-64::zstd-1.4.9-h19a0ad4_0
#
#
#
# Downloading and Extracting Packages
#
# zstd-1.4.9           | 478 KB    |            |   0%
# zstd-1.4.9           | 478 KB    | 3          |   3%
# zstd-1.4.9           | 478 KB    | ########## | 100%
# zstd-1.4.9           | 478 KB    | ########## | 100%
#
# pyqt-5.9.2           | 3.2 MB    |            |   0%
# pyqt-5.9.2           | 3.2 MB    | #####5     |  56%
# pyqt-5.9.2           | 3.2 MB    | ########## | 100%
# pyqt-5.9.2           | 3.2 MB    | ########## | 100%
#
# sip-4.19.13          | 262 KB    |            |   0%
# sip-4.19.13          | 262 KB    | ########## | 100%
# sip-4.19.13          | 262 KB    | ########## | 100%
#
# cycler-0.10.0        | 14 KB     |            |   0%
# cycler-0.10.0        | 14 KB     | ########## | 100%
#
# freetype-2.10.4      | 466 KB    |            |   0%
# freetype-2.10.4      | 466 KB    | ########## | 100%
# freetype-2.10.4      | 466 KB    | ########## | 100%
#
# lz4-c-1.9.3          | 131 KB    |            |   0%
# lz4-c-1.9.3          | 131 KB    | ########## | 100%
# lz4-c-1.9.3          | 131 KB    | ########## | 100%
#
# libpng-1.6.37        | 333 KB    |            |   0%
# libpng-1.6.37        | 333 KB    | ########## | 100%
# libpng-1.6.37        | 333 KB    | ########## | 100%
#
# matplotlib-3.3.4     | 27 KB     |            |   0%
# matplotlib-3.3.4     | 27 KB     | ########## | 100%
#
# tk-8.6.10            | 2.7 MB    |            |   0%
# tk-8.6.10            | 2.7 MB    | #########2 |  93%
# tk-8.6.10            | 2.7 MB    | ########## | 100%
#
# kiwisolver-1.3.1     | 52 KB     |            |   0%
# kiwisolver-1.3.1     | 52 KB     | ########## | 100%
#
# qt-5.9.7             | 72.5 MB   |            |   0%
# qt-5.9.7             | 72.5 MB   | 3          |   4%
# qt-5.9.7             | 72.5 MB   | 8          |   9%
# qt-5.9.7             | 72.5 MB   | #4         |  14%
# qt-5.9.7             | 72.5 MB   | #9         |  20%
# qt-5.9.7             | 72.5 MB   | ##4        |  25%
# qt-5.9.7             | 72.5 MB   | ##8        |  29%
# qt-5.9.7             | 72.5 MB   | ###4       |  34%
# qt-5.9.7             | 72.5 MB   | ###8       |  39%
# qt-5.9.7             | 72.5 MB   | ####4      |  44%
# qt-5.9.7             | 72.5 MB   | ####9      |  50%
# qt-5.9.7             | 72.5 MB   | #####4     |  55%
# qt-5.9.7             | 72.5 MB   | ######     |  60%
# qt-5.9.7             | 72.5 MB   | ######5    |  66%
# qt-5.9.7             | 72.5 MB   | #######    |  71%
# qt-5.9.7             | 72.5 MB   | #######6   |  76%
# qt-5.9.7             | 72.5 MB   | ########1  |  81%
# qt-5.9.7             | 72.5 MB   | ########6  |  87%
# qt-5.9.7             | 72.5 MB   | #########2 |  92%
# qt-5.9.7             | 72.5 MB   | #########7 |  97%
# qt-5.9.7             | 72.5 MB   | ########## | 100%
#
# icc_rt-2019.0.0      | 6.0 MB    |            |   0%
# icc_rt-2019.0.0      | 6.0 MB    | ###9       |  40%
# icc_rt-2019.0.0      | 6.0 MB    | ########## | 100%
# icc_rt-2019.0.0      | 6.0 MB    | ########## | 100%
#
# olefile-0.46         | 33 KB     |            |   0%
# olefile-0.46         | 33 KB     | ########## | 100%
# olefile-0.46         | 33 KB     | ########## | 100%
#
# icu-58.2             | 9.4 MB    |            |   0%
# icu-58.2             | 9.4 MB    | ##5        |  26%
# icu-58.2             | 9.4 MB    | ######7    |  68%
# icu-58.2             | 9.4 MB    | ########## | 100%
# icu-58.2             | 9.4 MB    | ########## | 100%
#
# libtiff-4.1.0        | 739 KB    |            |   0%
# libtiff-4.1.0        | 739 KB    | ########## | 100%
# libtiff-4.1.0        | 739 KB    | ########## | 100%
#
# pillow-8.2.0         | 671 KB    |            |   0%
# pillow-8.2.0         | 671 KB    | ########## | 100%
# pillow-8.2.0         | 671 KB    | ########## | 100%
#
# matplotlib-base-3.3. | 5.1 MB    |            |   0%
# matplotlib-base-3.3. | 5.1 MB    | ###7       |  37%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
# matplotlib-base-3.3. | 5.1 MB    | ########## | 100%
#
# xz-5.2.5             | 244 KB    |            |   0%
# xz-5.2.5             | 244 KB    | ########## | 100%
# xz-5.2.5             | 244 KB    | ########## | 100%
#
# scipy-1.6.2          | 13.0 MB   |            |   0%
# scipy-1.6.2          | 13.0 MB   | #7         |  17%
# scipy-1.6.2          | 13.0 MB   | ####5      |  46%
# scipy-1.6.2          | 13.0 MB   | ######9    |  69%
# scipy-1.6.2          | 13.0 MB   | #########8 |  99%
# scipy-1.6.2          | 13.0 MB   | ########## | 100%
#
# jpeg-9b              | 245 KB    |            |   0%
# jpeg-9b              | 245 KB    | ########## | 100%
# jpeg-9b              | 245 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
